# %%
import pandas as pd

# %%
def is_camel_case(s):
    capitalCount = len([char for char in s if char.isupper()])

    if capitalCount == 1 and s[0].isupper():
        return False
    
    return s != s.lower() and s != s.upper() and "_" not in s

# %%
boun = pd.read_csv('boun_hashformers_output.csv')
boun
# Out:
#      Unnamed: 0         hashtag   segmentedHashtag                 n1  \
# 0             0   tryingtosleep    trying to sleep    trying to sleep
# 1             1         mixture            mixture            mixture
# 2             2           runit             run it             run it
# 3             3      whatadream       what a dream       what a dream
# 4             4    keepitcoming     keep it coming     keep it coming
# ..          ...             ...                ...                ...
# 994         994  youareadumbass  you are a dumbass  you are a dumbass
# 995         995       newcast6e          newcast6e         newcast 6e
# 996         996      javajunkie        java junkie         javajunkie
# 997         997  abcfamilysucks   abc family sucks   abc family sucks
# 998         998    familytrippy      family trippy      family trippy
#
#                     n2                 n3                 n4  \
# 0       trying tosleep   try ing to sleep  try i ng to sleep
# 1             mi xture           m ixture          m i xture
# 2               r unit            run i t            r uni t
# 3          whata dream      w hat a dream       wha ta dream
# 4        keepit coming    keep it com ing    keep i t coming
# ..                 ...                ...                ...
# 994   youare a dumbass  youare a dumb ass   you area dumbass
# 995        new cast 6e        newcast 6 e         newcast6 e
# 996       j ava junkie        jav ajunkie        j avajunkie
# 997  a bc family sucks    abcfamily sucks   ab cfamily sucks
# 998     family tripp y     family t rippy     f amily trippy
#
#                       n5                  n6                  n7  \
# 0       trying t o sleep      tryingto sleep       tryingtosleep
# 1              m ix ture            mix ture            mixtur e
# 2                  runit              ru nit              runi t
# 3            w hatadream          whatadream         what adream
# 4           keepitcoming       keep itcoming      keepit com ing
# ..                   ...                 ...                 ...
# 994  you are a dumb as s  y ou are a dumbass  you are a dumb ass
# 995         new c as t6e           newcast6e          new cast6e
# 996          java junkie        jav a junkie        java junk ie
# 997      abc familysucks  a b c family sucks   ab c family sucks
# 998       fam ily trippy     family trip p y        familytrippy
#
#                    n8                 n9                 n10
# 0    tryi ng to sleep    tryingt o sleep    t rying to sleep
# 1            mixtu re           mixt ure           mi x ture
# 2             r u nit            ru n it             r un it
# 3       what a d ream      what a drea m       wh at a dream
# 4       keepitcom ing     keepi t coming     keep it comi ng
# ..                ...                ...                 ...
# 994   youarea dumbass  you area dumb ass  yo u are a dumbass
# 995      new cast 6 e         newca st6e         new cast6 e
# 996      ja va junkie      j av a junkie         ja vajunkie
# 997    abcfamilysucks  abc family suck s   a b cfamily sucks
# 998    family trip py      familytripp y       familyt rippy
#
# [999 rows x 13 columns]

# %%
camel_case = 0
for index, row in boun.iterrows():
    if is_camel_case(row['hashtag']):
        camel_case += 1
camel_case
# Out:
# 278

# %%
stan = pd.read_csv('stan_hashformers_output.csv')
stan
# Out:
#       Unnamed: 0           hashtag    segmentedHashtag                  n1  \
# 0              0              bait                bait                bait
# 1              1         thexfiles         the x files         the x files
# 2              2         vocaltips          vocal tips          vocal tips
# 3              3     adventureland       adventureland       adventureland
# 4              4         Furahiday           Furahiday           Furahiday
# ...          ...               ...                 ...                 ...
# 1007        1007       tastefringe        taste fringe         tastefringe
# 1008        1008         paparazzi           paparazzi           paparazzi
# 1009        1009  TWOHANDSFLETCHER  TWO HANDS FLETCHER  TWO HANDS FLETCHER
# 1010        1010        outrageous          outrageous          outrageous
# 1011        1011       ccwebdesign       cc web design        cc webdesign
#
#                      n2                   n3                   n4  \
# 0                 ba it                bai t                b ait
# 1             thexfiles          t hex files         the x file s
# 2           vocal tip s          vo cal tips           vocalt ips
# 3        ad ventureland       adventurel and      adventure l and
# 4            Furahi day           Fura hiday           F urahiday
# ...                 ...                  ...                  ...
# 1007      ta ste fringe        tas te fringe        tastef ring e
# 1008         pa parazzi           papara zzi          pap a razzi
# 1009  TWOHANDS FLETCHER  TW O HANDS FLETCHER  TWO H ANDS FLETCHER
# 1010        outrageo us         outrage o us          ou trageous
# 1011     c c web design        c cweb design         ccw ebdesign
#
#                       n5                n6                 n7  \
# 0                    NaN               NaN                NaN
# 1             the xfiles        thex files        th ex files
# 2            voc alt ips         vocaltips        voc al tips
# 3         adventurela nd    adventure land    ad venture land
# 4             Furahid ay      Fur a hi day         Furahida y
# ...                  ...               ...                ...
# 1007        taste fringe     tast e fringe       tast efringe
# 1008          papa razzi        paparazz i         p aparazzi
# 1009  T WOHANDS FLETCHER  TWOHANDSFLETCHER  TWO HANDSFLETCHER
# 1010         outrageou s       outrage ous        out rageous
# 1011         ccwebdesign     cc web design       ccweb design
#
#                       n8                  n9                  n10
# 0                    NaN                 NaN                  NaN
# 1             t hexfiles        th e x files           th exfiles
# 2            vocal t ips          vo caltips           voc altips
# 3         a dventureland      adventurelan d       adventur eland
# 4            Fu rahi day         Furah i day          Fur ahi day
# ...                  ...                 ...                  ...
# 1007        tastefring e        tastef ringe        taste f ringe
# 1008         p a parazzi         papa r azzi          papa razz i
# 1009  TWOHAN DS FLETCHER  TW OHANDS FLETCHER  TWO HANDS FLETCH ER
# 1010         o utrageous        out rage ous         outrage ou s
# 1011       c c webdesign        c cwebdesign        ccw eb design
#
# [1012 rows x 13 columns]

# %%
stan_small = pd.read_csv('stan-small_hashformers_output.csv')
stan_small
# Out:
#       Unnamed: 0                             hashtags  \
# 0              0                                Typo3
# 1              1                       KolacheFactory
# 2              2                          moanmondays
# 3              3                             semantic
# 4              4                            babypunch
# ...          ...                                  ...
# 1103        1103  ialreadysoldmysoultoplantsvszombies
# 1104        1104                        iamsograceful
# 1105        1105                              buffalo
# 1106        1106                         marsiscoming
# 1107        1107                                ims09
#
#                                          goldtruths  \
# 0                                    [Typo3, TYPO3]
# 1                                 [Kolache Factory]
# 2                                    [moan mondays]
# 3                                        [semantic]
# 4                                      [baby punch]
# ...                                             ...
# 1103  [i already sold my soul to plants vs zombies]
# 1104                             [i am so graceful]
# 1105                                      [buffalo]
# 1106               [Mars is coming, mars is coming]
# 1107                                       [ims 09]
#
#                                                n1  \
# 0                                          Typo 3
# 1                                 Kolache Factory
# 2                                    moan mondays
# 3                                        semantic
# 4                                       babypunch
# ...                                           ...
# 1103  i already sold my soul to plants vs zombies
# 1104                             i am so graceful
# 1105                                      buffalo
# 1106                               mars is coming
# 1107                                        ims09
#
#                                                 n2  \
# 0                                           Typ o3
# 1                                 Kolach e Factory
# 2                                     moanmon days
# 3                                        s emantic
# 4                                      ba by punch
# ...                                            ...
# 1103  i already sold my soul to plants vs zombie s
# 1104                               i amso graceful
# 1105                                      buffa lo
# 1106                                 marsis coming
# 1107                                       ims 0 9
#
#                                                 n3  \
# 0                                          Ty po 3
# 1                                 Kolache Factor y
# 2                                      moanmondays
# 3                                       se man tic
# 4                                       ba bypunch
# ...                                            ...
# 1103  i already sold my soul to pl ants vs zombies
# 1104                              ia m so graceful
# 1105                                     buff a lo
# 1106                               m ars is coming
# 1107                                        i ms09
#
#                                                 n4  \
# 0                                           T ypo3
# 1                                 Kol ache Factory
# 2                                    moan mon days
# 3                                        semanti c
# 4                                      bab y punch
# ...                                            ...
# 1103  i already sold my soul to plant s vs zombies
# 1104                               iams o graceful
# 1105                                      b uffalo
# 1106                               mar s is coming
# 1107                                        ims0 9
#
#                                               n5  \
# 0                                       T y po 3
# 1                               Ko lache Factory
# 2                                  mo an mondays
# 3                                     seman ti c
# 4                                    baby pun ch
# ...                                          ...
# 1103  i already sold my soul to plantsvs zombies
# 1104                            iam s o graceful
# 1105                                   buff al o
# 1106                            ma r s is coming
# 1107                                    i m s 09
#
#                                              n6  \
# 0                                         Typo3
# 1                                KolacheFactory
# 2                                mo an monday s
# 3                                     sema ntic
# 4                                   baby pu nch
# ...                                         ...
# 1103  i already sold my soul to plantsvszombies
# 1104                            iam so graceful
# 1105                                   buffal o
# 1106                               marsiscoming
# 1107                                     ims 09
#
#                                               n7  \
# 0                                         Ty po3
# 1                                Kolach eFactory
# 2                                  moan monday s
# 3                                      seman tic
# 4                                     baby punch
# ...                                          ...
# 1103  i already sold my soul to plants vszombies
# 1104                              iamso graceful
# 1105                                    buff alo
# 1106                               mars iscoming
# 1107                                      im s09
#
#                                                 n8  \
# 0                                          Typ o 3
# 1                                 K olache Factory
# 2                                     moanmonday s
# 3                                        se mantic
# 4                                       b abypunch
# ...                                            ...
# 1103  i already sold my soul to plan ts vs zombies
# 1104                               ia mso graceful
# 1105                                     buffa l o
# 1106                               mars i s coming
# 1107                                       im s 09
#
#                                                 n9  \
# 0                                          T ypo 3
# 1                                  KolacheFactor y
# 2                                    mo anmon days
# 3                                        semant ic
# 4                                     b a by punch
# ...                                            ...
# 1103  i already sold my soul to plants v s zombies
# 1104                             i a m so graceful
# 1105                                      bu ffalo
# 1106                               mars is com ing
# 1107                                       i ms 09
#
#                                             n10
# 0                                       T y po3
# 1                              Kola che Factory
# 2                                 moa n mondays
# 3                                    seman t ic
# 4                                   b aby punch
# ...                                         ...
# 1103  i already sold my soul toplantsvs zombies
# 1104                          i am so grace ful
# 1105                                  buf fa lo
# 1106                            ma rs is coming
# 1107                                    i m s09
#
# [1108 rows x 13 columns]

# %%
stan_large = pd.read_csv('stan-large_hashformers_output.csv')
stan_large
# Out:
#       Unnamed: 0       hashtags                        goldtruths  \
# 0              0             LT                              [LT]
# 1              1           imsb                            [imsb]
# 2              2  FollowWeekend  [follow weekend, Follow Weekend]
# 3              3     SkinSunday                     [Skin Sunday]
# 4              4           data                            [data]
# ...          ...            ...                               ...
# 9442        9442           DEMF                            [DEMF]
# 9443        9443          derby                           [derby]
# 9444        9444     damnheroin                     [damn heroin]
# 9445        9445         Samaya                          [Samaya]
# 9446        9446           Nats                            [nats]
#
#                   n1               n2               n3                n4  \
# 0                 LT              L T              NaN               NaN
# 1               imsb            ims b            i msb             im sb
# 2     Follow Weekend  Follow Week end  F ollow Weekend  Follow Week e nd
# 3        Skin Sunday     Sk in Sunday     Ski n Sunday       Ski nSunday
# 4               data            da ta            dat a            d at a
# ...              ...              ...              ...               ...
# 9442            DEMF            DEM F          D E M F             DE MF
# 9443           derby           derb y         d e r by           de r by
# 9444     damn heroin     damn hero in     dam n heroin       damnhero in
# 9445          Samaya          S amaya          Sama ya          S a maya
# 9446            Nats          N a t s           N at s             Nat s
#
#                  n5              n6               n7                n8  \
# 0               NaN             NaN              NaN               NaN
# 1               NaN             NaN              NaN               NaN
# 2     FollowWeekend  FollowWeek end  Follow We ekend  Follow We ek end
# 3     Sk i n Sunday      SkinSunday     S kin Sunday      Skin Sun day
# 4               NaN             NaN              NaN               NaN
# ...             ...             ...              ...               ...
# 9442            NaN             NaN              NaN               NaN
# 9443         der by          d erby          d er by           der b y
# 9444   damn her oin     dam nheroin       damnheroin      damn he roin
# 9445        Sam aya         Sa maya         Sam a ya        S a m ay a
# 9446            NaN             NaN              NaN               NaN
#
#                    n9              n10
# 0                 NaN              NaN
# 1                 NaN              NaN
# 2     Follow Weeken d  Follow Wee kend
# 3       S k in Sunday      S kinSunday
# 4                 NaN              NaN
# ...               ...              ...
# 9442              NaN              NaN
# 9443           de rby         d er b y
# 9444    damn hero i n     d amn heroin
# 9445        S a may a         Sa ma ya
# 9446              NaN              NaN
#
# [9447 rows x 13 columns]

# %%
camel_case = 0
for index, row in stan.iterrows():
    if is_camel_case(row['hashtag']):
        camel_case += 1
camel_case
# Out:
# 134

# %%
our = pd.read_csv('our_dataset_hashformers_output.csv')
our
# Out:
#       Unnamed: 0  Unnamed: 0.1                Hashtag  \
# 0              0             0                 bhoomi
# 1              1             1                dominos
# 2              2             2                psgfcgb
# 3              3             3             mazdoorno1
# 4              4             4  pappukabhibadleganahi
# ...          ...           ...                    ...
# 1896        1896          1985      masterchefturkiye
# 1897        1897          1986           imacelebrity
# 1898        1898          1987              merryxmas
# 1899        1899          1988      endbengalviolence
# 1900        1900          1989     varunchakaravarthy
#
#               segmentedHashtag                      1                       2  \
# 0                       bhoomi                 bhoomi                 bhoom i
# 1                      dominos                dominos                domino s
# 2                     psg fcgb                psgfcgb                psgfcg b
# 3                 mazdoor no 1             mazdoorno1             mazdoor no1
# 4     pappu kabhi badlega nahi  pappukabhibadleganahi  pappukabhibadleganah i
# ...                        ...                    ...                     ...
# 1896        masterchef turkiye      masterchefturkiye      masterchefturkiy e
# 1897           i m a celebrity           imacelebrity         i m a celebrity
# 1898                merry xmas             merry xmas             merry x mas
# 1899       end bengal violence      endbengalviolence      endbengalviolenc e
# 1900       varun chakaravarthy     varunchakaravarthy     varunchakaravarth y
#
#                            3                       4                       5  \
# 0                    bhoo mi                 bho omi                 b hoomi
# 1                   do minos                domi nos                domin os
# 2                   p sgfcgb                psgfc gb                ps gfcgb
# 3                mazdoorno 1            mazdoor no 1             m azdoorno1
# 4     pappukabhibadlegana hi  pappukabhibadlega nahi  p appukabhibadleganahi
# ...                      ...                     ...                     ...
# 1896      masterchefturki ye      m asterchefturkiye      masterchef turkiye
# 1897          im a celebrity           ima celebrity           imacelebrit y
# 1898               merryxmas              merryxm as              merryxma s
# 1899      e ndbengalviolence      en dbengalviolence      endbengalviolen ce
# 1900     v arunchakaravarthy     va runchakaravarthy     varun chakaravarthy
#
#                            6  ...                         n2  \
# 0                   bhoo m i  ...                    bhoo mi
# 1                   dom inos  ...                   do minos
# 2                   psg fcgb  ...                    psgfcgb
# 3                ma zdoorno1  ...                 mazdoorno1
# 4     pa ppukabhibadleganahi  ...  pappu kabhi badle ga nahi
# ...                      ...  ...                        ...
# 1896      mastercheftur kiye  ...       master chef turki ye
# 1897          i ma celebrity  ...              ima celebrity
# 1898              m erryxmas  ...                 merry xmas
# 1899      endbengal violence  ...        end ben galviolence
# 1900     varunchakaravar thy  ...        va runchakaravarthy
#
#                                n3                       n4  \
# 0                        bh oom i                  b hoomi
# 1                        d ominos                 dom inos
# 2                       psg fc gb                ps gf cgb
# 3                   maz door no 1           ma z door no 1
# 4     pappu ka bhi ba dle ga nahi  pappu kabhi badleganahi
# ...                           ...                      ...
# 1896          masterchef t urkiye      masterchef turk iye
# 1897               ima celebrit y            imac elebrity
# 1898                   merryx mas              me rry xmas
# 1899         end ben gal violence       endbeng alviolence
# 1900          var unchakaravarthy      v arunchakaravarthy
#
#                                n5                          n6  \
# 0                         bh oomi                     bhoom i
# 1                       dom i nos                    domino s
# 2                        ps gfcgb                   ps gfc gb
# 3                     maz doorno1                 mazdoor no1
# 4     pappu ka bhi bad le ga nahi  pappu ka bhi bad lega nahi
# ...                           ...                         ...
# 1896          masterche f turkiye         master chef turkiye
# 1897              im a cele brity             i m a celebrity
# 1898                  mer ry xmas                  me rryxmas
# 1899          endbeng al violence         end bengal violence
# 1900         va runcha karavarthy        v aruncha karavarthy
#
#                              n7                          n8  \
# 0                       bho omi                   b ho o mi
# 1                      domin os                   dom in os
# 2                      psgf cgb                    psgfc gb
# 3                   mazdoorno 1                maz door no1
# 4     pappu ka bhi badlega nahi  pappu ka bhi ba dlega nahi
# ...                         ...                         ...
# 1896         master chefturkiye           masterchefturkiye
# 1897             i ma celebrity                imacelebrity
# 1898                merry x mas                 m erry xmas
# 1899          endbengalviolence          endbengal violence
# 1900       va run chakaravarthy         varun chakaravarthy
#
#                               n9                          n10  \
# 0                       bh oo mi                     b hoo mi
# 1                      do min os                     domi nos
# 2                     p s gf cgb                    psg f cgb
# 3                   maz doorno 1                 mazdo or no1
# 4     pappu kabhi ba dle ga nahi  pap pu ka bhi badle ga nahi
# ...                          ...                          ...
# 1896         masterchef turki ye         master chef t urkiye
# 1897               im acelebrity               ima celebri ty
# 1898                  merryxma s                   m erryxmas
# 1899          en dbengalviolence          en dbengal violence
# 1900       va run cha karavarthy         v arunchak aravarthy
#
#                                            mutlitoken.1
# 0                        Hashtag has non english token
# 1                            Hashtag has named entities
# 2                            Hashtag has named entities
# 3                        Hashtag has non english token
# 4     {"choices": ["Hashtag has non english token ",...
# ...                                                 ...
# 1896                         Hashtag has named entities
# 1897                                               None
# 1898                         Hashtag has named entities
# 1899                         Hashtag has named entities
# 1900                         Hashtag has named entities
#
# [1901 rows x 37 columns]

# %%
our_lower = pd.read_csv('distant-sampled-lowercase_hashformers_output.csv')
our_lower
# Out:
#                    Unsegmented_hashtag                   Segmented_hashtag  \
# 0                      MinisterofState                    Ministerof State
# 1      PuducherryLoksabhaElections2019  Puducherry Loksabha Elections 2019
# 2              IndiaDeveleopmentDebate           India Develeopment Debate
# 3                          LokSabhaSet                       Lok Sabha Set
# 4                           DeafTalent                         Deaf Talent
# ...                                ...                                 ...
# 19995                   BumblebeeMovie                     Bumblebee Movie
# 19996                       IPKFGandhi                         IPKF Gandhi
# 19997                    HyderabadUrdu                      Hyderabad Urdu
# 19998                       NeckTattoo                         Neck Tattoo
# 19999                    OdishaKoraput                      Odisha Koraput
#
#          Unsegmented_hashtag_lowerCase         Segmented_hashtag_lowerCase  \
# 0                      ministerofstate                    ministerof state
# 1      puducherryloksabhaelections2019  puducherry loksabha elections 2019
# 2              indiadeveleopmentdebate           india develeopment debate
# 3                          loksabhaset                       lok sabha set
# 4                           deaftalent                         deaf talent
# ...                                ...                                 ...
# 19995                   bumblebeemovie                     bumblebee movie
# 19996                       ipkfgandhi                         ipkf gandhi
# 19997                    hyderabadurdu                      hyderabad urdu
# 19998                       necktattoo                         neck tattoo
# 19999                    odishakoraput                      odisha koraput
#
#                                         n1  \
# 0                        minister of state
# 1      puducherry lok sabha elections 2019
# 2               india dev eleopment debate
# 3                             lok sabhaset
# 4                              deaf talent
# ...                                    ...
# 19995                      bumblebee movie
# 19996                          ipkf gandhi
# 19997                       hyderabad urdu
# 19998                          neck tattoo
# 19999                       odisha koraput
#
#                                        n2  \
# 0                        minister ofstate
# 1      puducherrylok sabha elections 2019
# 2              india de veleopment debate
# 3                            loksabha set
# 4                             de aftalent
# ...                                   ...
# 19995                      bumblebeemovie
# 19996                        ipk f gandhi
# 19997                      hyderabadur du
# 19998                        n eck tattoo
# 19999                       odishakoraput
#
#                                         n3                                 n4  \
# 0                       minister o f state                 minister of stat e
# 1      puducherry loksa bha elections 2019  puducherry loksabha elections2019
# 2                indiad eveleopment debate           indiadeveleopment debate
# 3                            loksa bha set                      lok sabhas et
# 4                             de afta lent                        deaft alent
# ...                                    ...                                ...
# 19995                    bumble be e movie                   bumble be emovie
# 19996                          ipk fgandhi                       i pkf gandhi
# 19997                      hyderabad u rdu                     hyderabadu rdu
# 19998                         nec k tattoo                        necktatto o
# 19999                       odi shakoraput                    odish akora put
#
#                                          n5  \
# 0                           ministerofstate
# 1      pudu cherry lok sabha elections 2019
# 2                 india develeopment debate
# 3                             lok sa bhaset
# 4                              dea f talent
# ...                                     ...
# 19995                      bumblebee mov ie
# 19996                            ipkfgandhi
# 19997                      hyderabad u rd u
# 19998                          neck tat too
# 19999                       odish a koraput
#
#                                        n6                                  n7  \
# 0                        ministerof state                   minister o fstate
# 1      puducherry loksabha elections 2019  puducherry lok sabha elections2019
# 2                india develeopmentdebate          india devel eopment debate
# 3                           lok sabha set                         loksabhaset
# 4                              deaftalent                        de af talent
# ...                                   ...                                 ...
# 19995                    bumble bee movie                     bumble beemovie
# 19996                        ip kf gandhi                       ipk fg and hi
# 19997                       hyderabadurdu                     hyderabad ur du
# 19998                          necktattoo                        ne ck tattoo
# 19999                     odi shakora put                      odishakora put
#
#                                          n8  \
# 0                        min ister of state
# 1      puducherry lok sa bha elections 2019
# 2                   indiadeveleopmentdebate
# 3                            lok sa bha set
# 4                              de aftal ent
# ...                                     ...
# 19995                      bumblebe e movie
# 19996                           ip kfgandhi
# 19997                        hyderabadurd u
# 19998                           necktat too
# 19999                        odish akoraput
#
#                                       n9                                  n10
# 0                       ministerofstat e                   minister of s tate
# 1      puducherryloksabha elections 2019  puducherrylok sa bha elections 2019
# 2            india de vele opment debate          india dev ele opment debate
# 3                           loksa bhaset                       lok sab ha set
# 4                          d e af talent                          deafta lent
# ...                                  ...                                  ...
# 19995                    bumblebe emovie                     bumbleb ee movie
# 19996                       ipkfg and hi                        ip k f gandhi
# 19997                    hyderab ad urdu                      hyderabad urd u
# 19998                        n ecktattoo                         neck tatto o
# 19999                    odisha kora put                      odi sha koraput
#
# [20000 rows x 14 columns]

# %%
our_distant = pd.read_csv('distant-sampled_hashformers_output.csv')
our_distant
# Out:
#                    Unsegmented_hashtag                   Segmented_hashtag  \
# 0                      MinisterofState                    Ministerof State
# 1      PuducherryLoksabhaElections2019  Puducherry Loksabha Elections 2019
# 2              IndiaDeveleopmentDebate           India Develeopment Debate
# 3                          LokSabhaSet                       Lok Sabha Set
# 4                           DeafTalent                         Deaf Talent
# ...                                ...                                 ...
# 19995                   BumblebeeMovie                     Bumblebee Movie
# 19996                       IPKFGandhi                         IPKF Gandhi
# 19997                    HyderabadUrdu                      Hyderabad Urdu
# 19998                       NeckTattoo                         Neck Tattoo
# 19999                    OdishaKoraput                      Odisha Koraput
#
#          Unsegmented_hashtag_lowerCase         Segmented_hashtag_lowerCase  \
# 0                      ministerofstate                    ministerof state
# 1      puducherryloksabhaelections2019  puducherry loksabha elections 2019
# 2              indiadeveleopmentdebate           india develeopment debate
# 3                          loksabhaset                       lok sabha set
# 4                           deaftalent                         deaf talent
# ...                                ...                                 ...
# 19995                   bumblebeemovie                     bumblebee movie
# 19996                       ipkfgandhi                         ipkf gandhi
# 19997                    hyderabadurdu                      hyderabad urdu
# 19998                       necktattoo                         neck tattoo
# 19999                    odishakoraput                      odisha koraput
#
#        segments_count                                 n1  \
# 0                   2                  Minister of State
# 1                   4  PuducherryLoksabha Elections 2019
# 2                   3          India Develeopment Debate
# 3                   3                      Lok Sabha Set
# 4                   2                        Deaf Talent
# ...               ...                                ...
# 19995               2                    Bumblebee Movie
# 19996               2                        IPKF Gandhi
# 19997               2                     Hyderabad Urdu
# 19998               2                        Neck Tattoo
# 19999               2                     Odisha Koraput
#
#                                        n2                                 n3  \
# 0                        Minister ofState                 Minister o f State
# 1      Puducherry Lok sabhaElections 2019  Puducherry Loksabha Elections2019
# 2                India DeveleopmentDebate         India Dev eleopment Debate
# 3                          Lok Sabha S et                      Lok SabhaS et
# 4                            De af Talent                        D eafTalent
# ...                                   ...                                ...
# 19995                    Bumble bee Movie                   Bumblebee Movi e
# 19996                        IPK F Gandhi                      IP K F Gandhi
# 19997                     Hyderabad Ur du                     HyderabadU rdu
# 19998                        N eck Tattoo                       Nec k Tattoo
# 19999                      OdishaKora put                    Odisha Korapu t
#
#                                        n4                                  n5  \
# 0                      Minister of Stat e                  Minister of S tate
# 1      Puducherry Lok sabha Elections2019  PuducherryLok sabha Elections 2019
# 2             India Dev e leopment Debate            IndiaDeveleopment Debate
# 3                            LokSabha Set                        Lok SabhaSet
# 4                            Dea f Talent                       D e af Talent
# ...                                   ...                                 ...
# 19995                     BumblebeeMov ie                      BumblebeeMovie
# 19996                       I P KF Gandhi                      I P K F Gandhi
# 19997                      HyderabadUr du                       HyderabadUrdu
# 19998                        Ne ck Tattoo                        Neck Tat too
# 19999                     Odis ha Koraput                       OdishaKoraput
#
#                                         n6  \
# 0                          MinisterofState
# 1      Puducherry Loksab ha Elections 2019
# 2               India Devel eopment Debate
# 3                           Lok Sabha Se t
# 4                             Deaf Ta lent
# ...                                    ...
# 19995                      Bumble beeMovie
# 19996                         I PKF Gandhi
# 19997                       HyderabadUrd u
# 19998                         Neck Tatto o
# 19999                      Odisha Kora put
#
#                                         n7  \
# 0                         Ministerof State
# 1      Puducherry Lok sabha Elections 2019
# 2                  IndiaDeveleopmentDebate
# 3                          Lok Sabha S e t
# 4                               DeafTalent
# ...                                    ...
# 19995                     Bumblebee Mov ie
# 19996                         IP KF Gandhi
# 19997                      Hyderabad Urd u
# 19998                        Neck Tatt o o
# 19999                      Odisha K oraput
#
#                                        n8  \
# 0                     Minister of St at e
# 1      Puducherry Loksabha Elections 2019
# 2              India De veleopment Debate
# 3                           Lok SabhaSe t
# 4                            D eaf Talent
# ...                                   ...
# 19995                    Bumblebee Mo vie
# 19996                       I PK F Gandhi
# 19997                     Hyderabad U rdu
# 19998                          NeckTattoo
# 19999                     Odisha Korap ut
#
#                                         n9  \
# 0                       Minister of St ate
# 1      Puducherry Loks abha Elections 2019
# 2              India D evel eopment Debate
# 3                           Lok SabhaS e t
# 4                              Dea fTalent
# ...                                    ...
# 19995                     Bumblebe e Movie
# 19996                           IPKFGandhi
# 19997                      H yderabad Urdu
# 19998                          N eckTattoo
# 19999                      Odish a Koraput
#
#                                         n10
# 0                        Minister of Sta te
# 1      Puducherry Lok sa bha Elections 2019
# 2               India Deve l eopment Debate
# 3                               LokSabhaSet
# 4                               De afTalent
# ...                                     ...
# 19995                     Bumblebee Mov i e
# 19996                           IPK FGandhi
# 19997                       HyderabadU rd u
# 19998                          Neck Tatt oo
# 19999                      Odisha Kor a put
#
# [20000 rows x 15 columns]

# %%
camel_case = 0
for index, row in our.iterrows():
    if is_camel_case(row['Hashtag']):
        camel_case += 1
camel_case
# Out:
# 0

# %%
total = len(boun)
for n in range(1, 11):
    corr = 0
    for index, row in boun.iterrows():
        true = row['segmentedHashtag']
        for j in range(1, n+1):
            if true == row['n' + str(j)]:
                corr += 1
                break
    acc = corr/total * 100
    print(n, acc)
# Out:
# 1 83.68368368368368
# 2 87.68768768768768
# 3 88.18818818818819
# 4 88.58858858858859
# 5 91.3913913913914
# 6 96.7967967967968
# 7 98.998998998999
# 8 99.2992992992993
# 9 99.2992992992993
# 10 99.3993993993994

# %%
df = pd.DataFrame(columns=list(boun.columns))
i = 0
for index, row in boun.iterrows():
    true = row['segmentedHashtag']
    flag = 1
    for j in range(1, 11):
        if true == row['n' + str(j)]:
            flag = 0
    if flag:
        df.loc[i] = row
        i += 1
df
# Out:
#   Unnamed: 0                          hashtag  \
# 0        151  Guyswhoaresexyandbestbeknowinit
# 1        406       accuraterepresentationofme
# 2        649             ThoughtItWasInTheBag
# 3        713                    10thintheWest
# 4        731     LesDuosQuiOntMarqueLHistoire
# 5        992  giveyourheartabreakto100million
#
#                            segmentedHashtag  \
# 0  Guys who are sexy and best be know in it
# 1             accuratere presentation of me
# 2                 Thought It Was In The Bag
# 3                          10 thin the West
# 4         Les Duos Qui Ont Marque LHistoire
# 5    give your heart a break to 100 million
#
#                                      n1  \
# 0    Guys who are sexyandbestbeknowinit
# 1         accurate representation of me
# 2                  ThoughtItWasInTheBag
# 3                      10th in the West
# 4      Les Duos QuiOnt MarqueL Histoire
# 5  giveyourheart a break to 100 million
#
#                                       n2                                   n3  \
# 0        Guyswhoaresexyandbestbeknowinit  Guyswhoaresexyandbest be know in it
# 1           accuraterepresentation of me         accurate representation ofme
# 2                Thought It Was InTheBag               Thought It WasInTheBag
# 3                        10th in theWest                     10 th in theWest
# 4       Les Duo sQuiOnt MarqueL Histoire    Les Duo sQuiOnt Marque L Histoire
# 5  give yourheart a break to 100 million  giveyourheart a breakto 100 million
#
#                                      n4                                    n5  \
# 0     Guyswhoaresexyandbestbe know init    Guyswhoaresexyand best beknowin it
# 1         accurate representation ofm e            accuraterepresentationofme
# 2                 ThoughtItWasInThe Bag              Thought It Was In TheBag
# 3                     10th i n the West                       10th int heWest
# 4     Les Duos Qui Ont MarqueL Histoire       Les Duo sQuiOntMarqueL Histoire
# 5  give yourheart a break to 100million  giveyour heart a break to 100million
#
#                                    n6                                   n7  \
# 0  Guyswhoaresexyandbest be knowin it    Guyswhoaresexyandbestbe knowin it
# 1        accurate representationof me          accuraterepresentationof me
# 2              ThoughtItWasIn The Bag                ThoughtItWasIn TheBag
# 3                   10 th in the West                      10th inthe West
# 4  Les Duos Qui Ont Marque L Histoire    Les Duos QuiOnt Marque L Histoire
# 5  giveyourheart a break to100million  giveyourheart a break to 100million
#
#                                       n8                                   n9  \
# 0    Guyswhoare sexyandbest be knowin it    Guyswhoaresexyandbest beknowin it
# 1            accurate representationofme       accurate representation of m e
# 2                  Thought ItWasInTheBag                ThoughtIt WasInTheBag
# 3                       10th int he West                       10th intheWest
# 4    Les Duo s Qui Ont Marque L Histoire      Les Duos QuiOnt MarqueLHistoire
# 5  giveyour heart a break to 100 million  giveyourheart a break to100 million
#
#                                    n10
# 0  Guys who are sexyandbestbe knowinit
# 1       accurate representa tion of me
# 2              ThoughtItWas In The Bag
# 3                    1 0th in the West
# 4     Les Duos QuiOnt Marque LHistoire
# 5   giveyourheart a breakto100 million

# %%
camel_case = 0
for index, row in df.iterrows():
    if is_camel_case(row['hashtag']):
        camel_case += 1
camel_case
# Out:
# 3

# %%
df = pd.DataFrame(columns=list(boun.columns))
i = 0
for index, row in boun.iterrows():
    true = row['segmentedHashtag']
    flag = 1
    for j in range(1, 2):
        if true == row['n' + str(j)]:
            flag = 0
    if flag:
        df.loc[i] = row
        i += 1
df
# Out:
#     Unnamed: 0                          hashtag  \
# 0            6                       sportsnews
# 1            9                   thegrandmaster
# 2           16                      powercouple
# 3           34                        usairways
# 4           35                          Hoodrat
# ..         ...                              ...
# 158        981                          geekmom
# 159        987                      brainfuckit
# 160        992  giveyourheartabreakto100million
# 161        995                        newcast6e
# 162        996                       javajunkie
#
#                            segmentedHashtag  \
# 0                               sports news
# 1                           the grandmaster
# 2                              power couple
# 3                                us airways
# 4                                  Hood rat
# ..                                      ...
# 158                                geek mom
# 159                           brain fuck it
# 160  give your heart a break to 100 million
# 161                               newcast6e
# 162                             java junkie
#
#                                        n1  \
# 0                              sportsnews
# 1                        the grand master
# 2                             powercouple
# 3                               usairways
# 4                                 Hoodrat
# ..                                    ...
# 158                               geekmom
# 159                           brainfuckit
# 160  giveyourheart a break to 100 million
# 161                            newcast 6e
# 162                            javajunkie
#
#                                         n2  \
# 0                             s ports news
# 1                           thegrandmaster
# 2                            p ower couple
# 3                               us airways
# 4                                 Hoodra t
# ..                                     ...
# 158                               gee kmom
# 159                           brainfuck it
# 160  give yourheart a break to 100 million
# 161                            new cast 6e
# 162                           j ava junkie
#
#                                       n3  \
# 0                            sport snews
# 1                       t he grandmaster
# 2                           p owercouple
# 3                             usair ways
# 4                               Hoo drat
# ..                                   ...
# 158                            g eek mom
# 159                        brain fuck it
# 160  giveyourheart a breakto 100 million
# 161                          newcast 6 e
# 162                          jav ajunkie
#
#                                        n4  \
# 0                            sports new s
# 1                       t he grand master
# 2                           powe r couple
# 3                             us airway s
# 4                               Hoo dra t
# ..                                    ...
# 158                              g eekmom
# 159                          brain fuckit
# 160  give yourheart a break to 100million
# 161                            newcast6 e
# 162                           j avajunkie
#
#                                        n5                                  n6  \
# 0                            sport s news                         sports news
# 1                         t hegrandmaster                     the grandmaster
# 2                            powercoupl e                       pow er couple
# 3                              usa irways                         usair way s
# 4                               Hood r at                           Hood ra t
# ..                                    ...                                 ...
# 158                              geekmo m                           geek mo m
# 159                         brainfuck i t                      b rain fuck it
# 160  giveyour heart a break to 100million  giveyourheart a break to100million
# 161                          new c as t6e                           newcast6e
# 162                           java junkie                        jav a junkie
#
#                                       n7  \
# 0                            s portsnews
# 1                        thegrand master
# 2                           power couple
# 3                           usa i r ways
# 4                               Hood rat
# ..                                   ...
# 158                             geek mom
# 159                        b rain fuckit
# 160  giveyourheart a break to 100million
# 161                           new cast6e
# 162                         java junk ie
#
#                                         n8  \
# 0                            s port s news
# 1                         th e grandmaster
# 2                            power coup le
# 3                              us air ways
# 4                                 Hoodr at
# ..                                     ...
# 158                             geek m o m
# 159                           brainfucki t
# 160  giveyour heart a break to 100 million
# 161                           new cast 6 e
# 162                           ja va junkie
#
#                                       n9                                 n10
# 0                          s ports new s                         sportsn ews
# 1                      th e grand master                     th egrandmaster
# 2                          power coupl e                      power co u ple
# 3                             usairway s                         usa i rways
# 4                              Ho od rat                           H ood rat
# ..                                   ...                                 ...
# 158                            gee km om                           geek m om
# 159                         b rainfuckit                      brain f uck it
# 160  giveyourheart a break to100 million  giveyourheart a breakto100 million
# 161                           newca st6e                         new cast6 e
# 162                        j av a junkie                         ja vajunkie
#
# [163 rows x 13 columns]

# %%
camel_case = 0
for index, row in df.iterrows():
    if is_camel_case(row['hashtag']):
        camel_case += 1
camel_case
# Out:
# 32

# %%
total = len(stan)
for n in range(1, 11):
    corr = 0
    for index, row in stan.iterrows():
        true = row['segmentedHashtag']
        for j in range(1, n+1):
            if true == row['n' + str(j)]:
                corr += 1
                break
    acc = corr/total * 100
    print(n, acc)
# Out:
# 1 80.03952569169961
# 2 84.48616600790514
# 3 85.67193675889328
# 4 87.15415019762845
# 5 90.01976284584981
# 6 95.0592885375494
# 7 98.71541501976284
# 8 99.2094861660079
# 9 99.50592885375494
# 10 99.60474308300395

# %%
df = pd.DataFrame(columns=list(stan.columns))
i = 0
for index, row in stan.iterrows():
    true = row['segmentedHashtag']
    flag = 1
    for j in range(1, 11):
        if true == row['n' + str(j)]:
            flag = 0
    if flag:
        df.loc[i] = row
        i += 1
df
# Out:
#   Unnamed: 0                        hashtag  \
# 0        351                  thingsakassay
# 1        649                         occlln
# 2        751  redlinepleasedontmakemecutyou
# 3        814                  What_A_Legend
#
#                         segmentedHashtag                                   n1  \
# 0                       things aka s say                       thingsakas say
# 1                                 occlln                              oc clln
# 2  red line please don t make me cut you  redline please dont make me cut you
# 3                      What _ A _ Legend                        What_A_Legend
#
#                                      n2                                  n3  \
# 0                        thingsak assay                     things a kassay
# 1                            oc c l l n                           oc c l ln
# 2  red line please dont make me cut you  redlineplease dont make me cut you
# 3                        What_A_ Legend                      What _A_Legend
#
#                                   n4                                  n5  \
# 0                    things aka ssay                     thing sakas say
# 1                           oc c lln                            oc cll n
# 2  redlineplease dont make me cutyou  redline please dont make mecut you
# 3                    What_ A_ Legend                    What _ A_ Legend
#
#                                     n6                                  n7  \
# 0                        thingsakassay                      things akassay
# 1                            oc c ll n                             occl ln
# 2  red lineplease dont make me cut you  redline please dont make me cutyou
# 3                      What _A_ Legend                      What_A_Leg end
#
#                                      n8                                  n9  \
# 0                       things akas say                     things ak assay
# 1                           o c c l l n                             occ lln
# 2  redline please don t make me cut you  redline please dontmake me cut you
# 3                       What _A _Legend                      W hat_A_Legend
#
#                                    n10
# 0                     things a kas say
# 1                              o cclln
# 2  redlineplease don t make me cut you
# 3                     W hat _A_ Legend

# %%
camel_case = 0
for index, row in df.iterrows():
    if is_camel_case(row['hashtag']):
        camel_case += 1
camel_case
# Out:
# 0

# %%
df = pd.DataFrame(columns=list(stan.columns))
i = 0
for index, row in stan.iterrows():
    true = row['segmentedHashtag']
    flag = 1
    for j in range(1, 2):
        if true == row['n' + str(j)]:
            flag = 0
    if flag:
        df.loc[i] = row
        i += 1
df
# Out:
#     Unnamed: 0        hashtag segmentedHashtag              n1  \
# 0            8         PKMMDI           PKMMDI         PKM MDI
# 1            9  BAMcinemaFEST    BAMcinemaFEST  BAM cinemaFEST
# 2           10         TirNua           TirNua         Tir Nua
# 3           12       tangogps         tangogps       tango gps
# 4           14        OneRiot          OneRiot        One Riot
# ..         ...            ...              ...             ...
# 197        995      nanednews       naned news     na ned news
# 198        996        losnotc          losnotc       los no tc
# 199       1006       jongtuig        jong tuig        jongtuig
# 200       1007    tastefringe     taste fringe     tastefringe
# 201       1011    ccwebdesign    cc web design    cc webdesign
#
#                   n2              n3                n4                n5  \
# 0            PK MMDI          PKMMDI          PK M MDI         PK MM D I
# 1    BAM cinema FEST  BAMcinema FEST  BAM cinema F EST  BAM cinema FES T
# 2           T ir Nua         T irNua         T ir N ua           Ti rNua
# 3         tan go gps      tang o gps        ta ngo gps       t an go gps
# 4          O ne Riot       One Rio t         On e Riot           OneRiot
# ..               ...             ...               ...               ...
# 197       naned news     nan ed news         nanednews        na nednews
# 198          losnotc        los notc         lo sno tc          losnot c
# 199        jong tuig       jon gtuig        jong tu ig        jongtu i g
# 200    ta ste fringe   tas te fringe     tastef ring e      taste fringe
# 201   c c web design   c cweb design      ccw ebdesign       ccwebdesign
#
#                 n6                n7               n8                 n9  \
# 0          PKMM DI          PK MM DI         PKM MD I           P K MMDI
# 1    BAMcinemaFEST  BAM cinema FE ST  B AM cinemaFEST  BAM cinema F E ST
# 2           TirNua          Tir Nu a         Ti r Nua          T i r Nua
# 3      tango g p s          tangogps       tango gp s         tango g ps
# 4         On eRiot          O neRiot        One R iot         O n e Riot
# ..             ...               ...              ...                ...
# 197     nan ednews      n an ed news       nane dnews       na n ed news
# 198      los not c          losno tc         lo snotc           losn otc
# 199     jong tui g         jongtu ig        jongt uig         jong t uig
# 200  tast e fringe      tast efringe     tastefring e       tastef ringe
# 201  cc web design      ccweb design    c c webdesign       c cwebdesign
#
#                  n10
# 0          P K M MDI
# 1    BAMcinema FE ST
# 2          T ir Nu a
# 3          tangog ps
# 4         O ne Rio t
# ..               ...
# 197      n aned news
# 198        lo snot c
# 199        jongtui g
# 200    taste f ringe
# 201    ccw eb design
#
# [202 rows x 13 columns]

# %%
camel_case = 0
for index, row in df.iterrows():
    if is_camel_case(row['hashtag']):
        camel_case += 1
camel_case
# Out:
# 27

# %%
total = len(stan_small)
for n in range(1, 11):
    corr = 0
    for index, row in stan_small.iterrows():
        true = row['goldtruths'].strip('][').split(', ')
        for j in range(1, n+1):
            if str(row['n' + str(j)]) in true:
                corr += 1
                break
    acc = corr/total * 100
    print(n, acc)
# Out:
# 1 80.05415162454874
# 2 85.10830324909747
# 3 85.1985559566787
# 4 85.83032490974729
# 5 88.89891696750902
# 6 94.7653429602888
# 7 97.11191335740072
# 8 97.29241877256317
# 9 97.3826714801444
# 10 97.3826714801444

# %%
total = len(stan_large)
for n in range(1, 11):
    corr = 0
    for index, row in stan_large.iterrows():
        true = row['goldtruths'].strip('][').split(', ')
        for j in range(1, n+1):
            if str(row['n' + str(j)]) in true:
                corr += 1
                break
    acc = corr/total * 100
    print(n, acc)
# Out:
# 1 72.17105959563884
# 2 75.73832962845349
# 3 76.33111040541971
# 4 76.76511061712714
# 5 79.25267280618186
# 6 83.32804064782471
# 7 85.38160262517202
# 8 85.66740764263787
# 9 85.81560283687944
# 10 85.85794432094845

# %%
total = len(our)
for n in range(1, 11):
    corr = 0
    for index, row in our.iterrows():
        true = row['segmentedHashtag']
        for j in range(1, n+1):
            if true == row['n' + str(j)]:
                corr += 1
                break
    acc = corr/total * 100
    print(n, acc)
# Out:
# 1 56.70699631772751
# 2 68.54287217254077
# 3 71.6991057338243
# 4 74.11888479747502
# 5 78.2219884271436
# 6 86.11257233035245
# 7 91.53077327722251
# 8 93.31930562861652
# 9 94.00315623356128
# 10 94.3713834823777

# %%
df = pd.DataFrame(columns=list(our.columns))
i = 0
for index, row in our.iterrows():
    true = row['segmentedHashtag']
    flag = 1
    for j in range(1, 11):
        if true == row['n' + str(j)]:
            flag = 0
    if flag:
        df.loc[i] = row
        i += 1
df
# Out:
#     Unnamed: 0 Unnamed: 0.1                    Hashtag  \
# 0            4            4      pappukabhibadleganahi
# 1            8            8       lastdayofmynrtraeors
# 2           12           12  1yearofitabestjodiashdeep
# 3           29           30             itirafediyorum
# 4          100          102            maibhichoukidar
# ..         ...          ...                        ...
# 102       1839         1926      kaditehansbyatifaslam
# 103       1841         1928     happybdaybestcmysjagan
# 104       1859         1946        cgswabhimaanke2saal
# 105       1878         1967      hbdsuperstarannaatthe
# 106       1882         1971         itrfilekarojhatpat
#
#                    segmentedHashtag                          1  \
# 0          pappu kabhi badlega nahi      pappukabhibadleganahi
# 1          last day of mynrtra eors       lastdayofmynrtraeors
# 2    1year of ita best jodi ashdeep  1yearofitabestjodiashdeep
# 3                   itiraf ediyorum             itirafediyorum
# 4                 mai bhi choukidar            maibhichoukidar
# ..                              ...                        ...
# 102      kadi te hans by atif aslam      kaditehansbyatifaslam
# 103     happy bday best cm ys jagan     happybdaybestcmysjagan
# 104         cg swabhimaan ke 2 saal        cgswabhimaanke2saal
# 105         hbd superstar annaatthe      hbdsuperstarannaatthe
# 106           itr file karo jhatpat         itrfilekarojhatpat
#
#                               2                           3  \
# 0        pappukabhibadleganah i      pappukabhibadlegana hi
# 1         lastdayofmynrtraeor s       la stdayofmynrtraeors
# 2    1yearofitabestjodiashdee p  1yearofitabestjodiash deep
# 3               itirafediyoru m             i tirafediyorum
# 4              maibhichoukida r            m aibhichoukidar
# ..                          ...                         ...
# 102      kaditehansbyatifasla m      kaditehansbyatifasl am
# 103     happybdaybestcmysjag an     happybdaybestcmysjaga n
# 104        cgswabhimaanke2sa al        cgswabhimaanke2saa l
# 105      hbdsuperstarannaat the      hbdsuperstarannaatt he
# 106         itrfilekarojhatp at         itrfilekarojhatpa t
#
#                               4                           5  \
# 0        pappukabhibadlega nahi      p appukabhibadleganahi
# 1         last dayofmynrtraeors       lastdayofmynrtraeo rs
# 2    1 yearofitabestjodiashdeep  1yearofitabestjodiashde ep
# 3               it irafediyorum             itirafediyor um
# 4              maibhichouki dar            ma ibhichoukidar
# ..                          ...                         ...
# 102      k aditehansbyatifaslam      ka ditehansbyatifaslam
# 103     ha ppybdaybestcmysjagan     h appybdaybestcmysjagan
# 104        c gswabhimaanke2saal        cgswabhimaanke2 saal
# 105      hbdsuperstarannaatth e     hbdsuperstaranna at the
# 106         i trfilekarojhatpat         it rfilekarojhatpat
#
#                               6  ...                             n2  \
# 0        pa ppukabhibadleganahi  ...      pappu kabhi badle ga nahi
# 1         l astdayofmynrtraeors  ...      last day of my nrtra eors
# 2    1year ofitabestjodiashdeep  ...  1 yearofita best jodi ashdeep
# 3               itirafediyo rum  ...                itira fediyorum
# 4              maibhichoukid ar  ...            mai bhi chou ki dar
# ..                          ...  ...                            ...
# 102      kaditehansbyatifas lam  ...        kadi tehans byatifaslam
# 103     happy bdaybestcmysjagan  ...     happy bday best cmys jagan
# 104        cgswabhimaanke2s aal  ...        cgsw abhimaan ke 2 saal
# 105      h bdsuperstarannaatthe  ...     hbd super star anna at the
# 106         itrfilekarojhat pat  ...          i tr file karojhatpat
#
#                               n3                             n4  \
# 0    pappu ka bhi ba dle ga nahi        pappu kabhi badleganahi
# 1      last day of my nrt raeors     last day of my n r traeors
# 2     1 yearofitabestjodiashdeep  1 yearof itabest jodi ashdeep
# 3              iti ra fedi yorum             iti ra fe di yorum
# 4              maibhichou ki dar             maibhi chou ki dar
# ..                           ...                            ...
# 102      kadi te hansbyatifaslam        kaditehansby at ifaslam
# 103       happybdaybestcmysjagan    happy bday best c my sjagan
# 104        cgsw abhimaan ke2saal        cgsw abhi maan ke2 saal
# 105    hbd super staranna at the        hbd superstaranna atthe
# 106       i tr file karoj hatpat           itr file karojhatpat
#
#                                n5                              n6  \
# 0     pappu ka bhi bad le ga nahi      pappu ka bhi bad lega nahi
# 1       last day of my nrtr aeors       last day of my nrtrae ors
# 2    1 year of itabestjodiashdeep  1 year ofita best jodi ashdeep
# 3                iti ra fediyorum                 iti rafediyorum
# 4                maibhichoukid ar              mai bhi chouki dar
# ..                            ...                             ...
# 102      kadi te hansbyati faslam         kadi tehansbyati faslam
# 103      happybday best cmysjagan       happy bdaybest cmy sjagan
# 104        cgsw abhimaanke 2 saal          cgswab him aanke2 saal
# 105       hbdsuperstaranna at the        hbd superstaranna at the
# 106       i tr file karoj hat pat           itr file karoj hatpat
#
#                               n7                           n8  \
# 0      pappu ka bhi badlega nahi   pappu ka bhi ba dlega nahi
# 1       last day of my nrtraeors   last day of my nr tra eors
# 2    1yearofitabest jodi ashdeep  1 yearofitabest jodiashdeep
# 3                itir afediyorum            iti ra fe diyorum
# 4               maibhichou kidar             maibhichouki dar
# ..                           ...                          ...
# 102       kadi tehansbyatifaslam      kaditehans by atifaslam
# 103   happy bday best cmy sjagan      happy bdaybestcmysjagan
# 104      cgsw abhima anke 2 saal        cgsw abhimaanke2 saal
# 105      hbd superstarannaat the     hbd superstar anna atthe
# 106      i tr file kar oj hatpat       i tr file karo jhatpat
#
#                                  n9                           n10  \
# 0        pappu kabhi ba dle ga nahi   pap pu ka bhi badle ga nahi
# 1        last day of my nr trae ors          lastdayofmynrtraeors
# 2    1 yearof ita best jodi ashdeep  1yearofita best jodi ashdeep
# 3                  iti raf ediyorum              it ira fediyorum
# 4                  maibhic houkidar             maibhichou kid ar
# ..                              ...                           ...
# 102        kadi tehans by atifaslam      kadi te hans byatifaslam
# 103        happy bday bestcmysjagan      happy bdaybest cmysjagan
# 104          cgsw abhima anke2 saal      cgsw abhi maan ke 2 saal
# 105        hbdsuperstar anna at the     hbdsuper star anna at the
# 106          i tr file karojhat pat       i tr file karo j hatpat
#
#                                           mutlitoken.1
# 0    {"choices": ["Hashtag has non english token ",...
# 1                           Hashtag has named entities
# 2    {"choices": ["Hashtag has non english token ",...
# 3                                                 None
# 4                       Hashtag has non english token
# ..                                                 ...
# 102                         Hashtag has named entities
# 103                         Hashtag has named entities
# 104  {"choices": ["Hashtag has non english token ",...
# 105                         Hashtag has named entities
# 106  {"choices": ["Hashtag has non english token ",...
#
# [107 rows x 37 columns]

# %%
import json
non_eng = 0
ner = 0
for index, row in df.iterrows():
    if row['mutlitoken'] == 'Hashtag has non english token ':
        non_eng += 1
    if row['mutlitoken'][0] == '{':
        if 'Hashtag has non english token ' in json.loads(row['mutlitoken'])['choices']:
            non_eng += 1
    if row['mutlitoken'] == 'Hashtag has named entities':
        ner += 1
    if row['mutlitoken'][0] == '{':   
        if 'Hashtag has named entities' in json.loads(row['mutlitoken'])['choices']:
            ner += 1

# %%
ner
# Out:
# 83

# %%
non_eng
# Out:
# 36

# %%
ner/len(df)*100
# Out:
# 77.57009345794393

# %%
non_eng/len(df)*100
# Out:
# 33.64485981308411

# %%
underscore = 0
for index, row in boun.iterrows():
    if '_' in row['hashtag']:
        underscore += 1
underscore
# Out:
# 0

# %%
underscore = 0
for index, row in stan.iterrows():
    if '_' in row['hashtag']:
        underscore += 1
        print(row['hashtag'])
underscore
# Out:
# clothes_overview
# drunk_bowling
# much_love
# CFC_Match3
# weather_me
# What_A_Legend
# flashcamp_uk
# 7

# %%
underscore = 0
for index, row in our.iterrows():
    if '_' in row['Hashtag']:
        underscore += 1
underscore
# Out:
# 0

# %%
total = len(our_lower)
for n in range(1, 11):
    corr = 0
    for index, row in our_lower.iterrows():
        true = row['Segmented_hashtag_lowerCase']
        for j in range(1, n+1):
            if true == row['n' + str(j)]:
                corr += 1
                break
    acc = corr/total * 100
    print(n, acc)
# Out:
# 1 47.43
# 2 58.589999999999996
# 3 62.09
# 4 64.55499999999999
# 5 69.53
# 6 77.67500000000001
# 7 82.785
# 8 84.96000000000001
# 9 86.02499999999999
# 10 86.665

# %%
total = len(our_distant)
for n in range(1, 11):
    corr = 0
    for index, row in our_distant.iterrows():
        true = row['Segmented_hashtag']
        for j in range(1, n+1):
            if true == row['n' + str(j)]:
                corr += 1
                break
    acc = corr/total * 100
    print(n, acc)
# Out:
# 1 72.47
# 2 77.12
# 3 78.69500000000001
# 4 79.905
# 5 83.005
# 6 88.465
# 7 91.66499999999999
# 8 92.78999999999999
# 9 93.41000000000001
# 10 93.76
